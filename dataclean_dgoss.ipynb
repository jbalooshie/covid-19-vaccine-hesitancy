# %%
# Import dependencies including SQLAlchamy
import pandas as pd
import numpy as np

from sqlalchemy import create_engine
import psycopg2

from config import db_password

# %%
# Create SQL engine
db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/vaccine_hesitancy"                                                                                        
engine = create_engine(db_string)

# %%
# Convert postgres tables to dataframes
census_demographic_df = pd.read_sql_table("census_demographic", db_string)
vaccine_hesitancy_df = pd.read_sql_table("vaccine_hesitancy_covid", db_string)
county_statistics_df = pd.read_sql_table("county_statistics", db_string)
county_size_df = pd.read_sql_table("county_size", db_string)
full_county_data_df = pd.read_sql_table("full_county_data", db_string)

# %%
# Drop the null columns where all values are null
census_demographic_df = census_demographic_df.dropna(axis='columns', how='all')

# Drop null rows
census_demographic_df = census_demographic_df.dropna()

# Print Dataframe
census_demographic_df.head()
# Out:
#    CountyId    State          County  TotalPop    Men   Women  Hispanic  \
# 0      1001  Alabama  Autauga County     55036  26899   28137       2.7
# 1      1003  Alabama  Baldwin County    203360  99527  103833       4.4
# 2      1005  Alabama  Barbour County     26201  13976   12225       4.2
# 3      1007  Alabama     Bibb County     22580  12251   10329       2.4
# 4      1009  Alabama   Blount County     57667  28490   29177       9.0
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   75.4   18.9     0.3  ...   0.6          1.3         2.5         25.8
# 1   83.1    9.5     0.8  ...   0.8          1.1         5.6         27.0
# 2   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 3   74.6   22.0     0.4  ...   0.3          1.7         1.5         30.0
# 4   87.4    1.5     0.3  ...   0.4          0.4         2.1         35.0
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0     24112         74.1        20.2           5.6         0.1           5.2
# 1     89527         80.7        12.9           6.3         0.1           5.5
# 2      8878         74.1        19.1           6.5         0.3          12.4
# 3      8171         76.0        17.4           6.3         0.3           8.2
# 4     21380         83.9        11.9           4.0         0.1           4.9
#
# [5 rows x 37 columns]

# %%
# Drop the null columns where all values are null
vaccine_hesitancy_df = vaccine_hesitancy_df.dropna(axis='columns', how='all')

# Drop null rows
vaccine_hesitancy_df = vaccine_hesitancy_df.dropna()

# Print Dataframe
vaccine_hesitancy_df.head()
# Out:
#    fips_code                   county    state  est_hesitant  \
# 0       1001  Autauga County, Alabama  ALABAMA          0.22
# 1       1003  Baldwin County, Alabama  ALABAMA          0.20
# 2       1005  Barbour County, Alabama  ALABAMA          0.23
# 3       1007     Bibb County, Alabama  ALABAMA          0.24
# 4       1009   Blount County, Alabama  ALABAMA          0.23
#
#    est_strongly_hesitant   svi             svi_category  cvac  \
# 0                   0.10  0.44   Moderate Vulnerability  0.61
# 1                   0.10  0.22        Low Vulnerability  0.23
# 2                   0.11  1.00  Very High Vulnerability  0.89
# 3                   0.12  0.60       High Vulnerability  0.76
# 4                   0.11  0.42   Moderate Vulnerability  0.80
#
#              cvac_category  percent_fully_vaccinated  percent_hispanic  \
# 0       High Vulnerability                     0.114            0.0283
# 1        Low Vulnerability                     0.176            0.0456
# 2  Very High Vulnerability                     0.128            0.0436
# 3       High Vulnerability                     0.115            0.0257
# 4       High Vulnerability                     0.095            0.0926
#
#    percent_american_indian_alaska_native  percent_asian  percent_black  \
# 0                                 0.0025         0.0103         0.1900
# 1                                 0.0065         0.0092         0.0917
# 2                                 0.0029         0.0048         0.4744
# 3                                 0.0013         0.0012         0.2214
# 4                                 0.0007         0.0037         0.0153
#
#    percent_hawaiian_pacific  percent_white            geographical_point  \
# 0                    0.0001         0.7460  POINT (-86.844516 32.756889)
# 1                    0.0000         0.8307  POINT (-86.844516 32.756889)
# 2                    0.0000         0.4581  POINT (-86.844516 32.756889)
# 3                    0.0000         0.7453  POINT (-86.844516 32.756889)
# 4                    0.0004         0.8689  POINT (-86.844516 32.756889)
#
#   state_code                                    county_boundary  \
# 0         AL  MULTIPOLYGON (((-86.90309599999999 32.54062599...
# 1         AL  MULTIPOLYGON (((-87.990684 30.55549, -87.98783...
# 2         AL  MULTIPOLYGON (((-85.429819 32.045983, -85.4303...
# 3         AL  MULTIPOLYGON (((-87.312265 33.086219, -87.3121...
# 4         AL  MULTIPOLYGON (((-86.74918799999999 33.997596, ...
#
#                                       state_boundary
# 0  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 1  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 2  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 3  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...
# 4  MULTIPOLYGON (((-88.139988 34.581703, -88.1352...

# %%
# Drop the null columns where all values are null
county_statistics_df = county_statistics_df.dropna(axis='columns', how='all')

# Drop null rows
county_statistics_df = county_statistics_df.dropna()

# Print DataFrame
county_statistics_df.head()
# Out:
#    fips_code          county state  percentage16_Donald_Trump  \
# 0       1001  autauga county    AL                      0.734
# 1       1003  baldwin county    AL                      0.774
# 2       1005  barbour county    AL                      0.523
# 3       1007     bibb county    AL                      0.770
# 4       1009   blount county    AL                      0.899
#
#    percentage16_Hillary_Clinton  total_votes16  votes16_Donald_Trump  \
# 0                         0.240        24661.0               18110.0
# 1                         0.196        94090.0               72780.0
# 2                         0.467        10390.0                5431.0
# 3                         0.214         8748.0                6733.0
# 4                         0.085        25384.0               22808.0
#
#    votes16_Hillary_Clinton  percentage20_Donald_Trump  percentage20_Joe_Biden  \
# 0                   5908.0                      0.715                   0.270
# 1                  18409.0                      0.762                   0.223
# 2                   4848.0                      0.536                   0.456
# 3                   1874.0                      0.784                   0.207
# 4                   2150.0                      0.896                   0.096
#
#    ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0  ...   0.6          1.3         2.5         25.8   24112.0         74.1
# 1  ...   0.8          1.1         5.6         27.0   89527.0         80.7
# 2  ...   2.2          1.7         1.3         23.4    8878.0         74.1
# 3  ...   0.3          1.7         1.5         30.0    8171.0         76.0
# 4  ...   0.4          0.4         2.1         35.0   21380.0         83.9
#
#    PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0        20.2           5.6         0.1           5.2
# 1        12.9           6.3         0.1           5.5
# 2        19.1           6.5         0.3          12.4
# 3        17.4           6.3         0.3           8.2
# 4        11.9           4.0         0.1           4.9
#
# [5 rows x 51 columns]

# %%
# Drop the null columns where all values are null
county_size_df = county_size_df.dropna(axis='columns', how='all')

# Drop null rows
county_size_df = county_size_df.dropna()

# Print DataFrame
county_size_df.head()
# Out:
#    fips_code          county state  population density
# 0       1001  Autauga County    AL       55514   urban
# 1       1003  Baldwin County    AL      190790   urban
# 2       1005  Barbour County    AL       27201   rural
# 3       1007     Bibb County    AL       22597   urban
# 4       1009   Blount County    AL       57826   urban

# %%
# Drop the null columns where all values are null
full_county_data_df = full_county_data_df.dropna(axis='columns', how='all')

# Drop null rows
full_county_data_df = full_county_data_df.dropna()

# Print DataFrame
full_county_data_df.head()
# Out:
#    fips_code                   county    state  est_hesitant  \
# 0     1001.0  Autauga County, Alabama  ALABAMA          0.22
# 1     1003.0  Baldwin County, Alabama  ALABAMA          0.20
# 2     1005.0  Barbour County, Alabama  ALABAMA          0.23
# 3     1007.0     Bibb County, Alabama  ALABAMA          0.24
# 4     1009.0   Blount County, Alabama  ALABAMA          0.23
#
#    est_strongly_hesitant   svi             svi_category  cvac  \
# 0                   0.10  0.44   Moderate Vulnerability  0.61
# 1                   0.10  0.22        Low Vulnerability  0.23
# 2                   0.11  1.00  Very High Vulnerability  0.89
# 3                   0.12  0.60       High Vulnerability  0.76
# 4                   0.11  0.42   Moderate Vulnerability  0.80
#
#              cvac_category  percent_fully_vaccinated  ...  Walk  OtherTransp  \
# 0       High Vulnerability                     0.114  ...   0.6          1.3
# 1        Low Vulnerability                     0.176  ...   0.8          1.1
# 2  Very High Vulnerability                     0.128  ...   2.2          1.7
# 3       High Vulnerability                     0.115  ...   0.3          1.7
# 4       High Vulnerability                     0.095  ...   0.4          0.4
#
#    WorkAtHome  MeanCommute  Employed  PrivateWork PublicWork SelfEmployed  \
# 0         2.5         25.8     24112         74.1       20.2          5.6
# 1         5.6         27.0     89527         80.7       12.9          6.3
# 2         1.3         23.4      8878         74.1       19.1          6.5
# 3         1.5         30.0      8171         76.0       17.4          6.3
# 4         2.1         35.0     21380         83.9       11.9          4.0
#
#   FamilyWork Unemployment
# 0        0.1          5.2
# 1        0.1          5.5
# 2        0.3         12.4
# 3        0.3          8.2
# 4        0.1          4.9
#
# [5 rows x 57 columns]
